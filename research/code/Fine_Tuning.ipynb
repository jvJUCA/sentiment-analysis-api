# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.14)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.4)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.7)

# %%
# !kaggle datasets download -d lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
# Out:
# Dataset URL: https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
# License(s): other
# Downloading imdb-dataset-of-50k-movie-reviews.zip to /content
#  66% 17.0M/25.7M [00:00<00:00, 46.5MB/s]
# 100% 25.7M/25.7M [00:00<00:00, 62.4MB/s]

# %%
# !unzip imdb-dataset-of-50k-movie-reviews.zip
# Out:
# Archive:  imdb-dataset-of-50k-movie-reviews.zip
#   inflating: IMDB Dataset.csv

# %%
# import pandas as pd
# df = pd.read_csv('/content/IMDB Dataset.csv')
# def to_sentiment(rating):
#   rating = str(rating)
#   if rating == 'positive':
#     return 0
#   else:
#     return 1

# df['sentiment'] = df.sentiment.apply(to_sentiment)
# print(df.sample(5))
# df.to_csv('/content/IMDB Dataset_clean.csv', index=False)

# %%
# %matplotlib inline
# %load_ext autoreload

# %%
# !pip install pandas_profiling
# !pip install pydantic==1.8.2

# %%
import pandas as pd
import numpy as np
import transformers
from transformers import BertModel, BertTokenizer, AdamW, get_linear_schedule_with_warmup
import seaborn as sns

import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

from sklearn.model_selection import train_test_split

from collections import defaultdict

import matplotlib.pyplot as plt
from textwrap import wrap



import gc



RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

MAX_LEN = 400
BATCH_SIZE = 8

class_names = ['negative', 'positive']
EPOCHS = 2

# %%
# df = pd.read_csv('/content/IMDB Dataset_clean.csv',nrows=100)
df = pd.read_csv('/content/IMDB Dataset_clean.csv')
print(len(df))
print(df.sample(5))
# Out:
# 50000
#                                                   review  sentiment
# 33553  I really liked this Summerslam due to the look...          0
# 9427   Not many television shows appeal to quite as m...          0
# 199    The film quickly gets to a major chase scene w...          1
# 12447  Jane Austen would definitely approve of this o...          0
# 39489  Expectations were somewhat high for me when I ...          1

# %% [markdown]
#  Using cased version of BERT and tokenizer.

# %%
PRE_TRAINED_MODEL_NAME = 'bert-base-cased'

# %%
tokenizer = BertTokenizer.from_pretrained(PRE_TRAINED_MODEL_NAME)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
# Testing Tokenizer
sample_txt = 'I want to learn how to do sentiment analysis using BERT and tokenizer.'

encoding = tokenizer.encode_plus(
  sample_txt,
  max_length=32,
  add_special_tokens=True, # Add '[CLS]' and '[SEP]'
  return_token_type_ids=False,
  pad_to_max_length=True,
  return_attention_mask=True,
  return_tensors='pt',  # Return PyTorch tensors
  truncation = True
)

print(encoding.keys())
# Out:
# dict_keys(['input_ids', 'attention_mask'])
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
class MovieReviewDataset(Dataset):
  def __init__(self, reviews, targets, tokenizer, max_len):
    self.reviews = reviews
    self.targets = targets # Labels
    self.tokenizer = tokenizer
    self.max_len = max_len

  def __len__(self):
    return len(self.reviews)

  def __getitem__(self, item):
    review = str(self.reviews[item])
    target = self.targets[item]


    # Tokenize with max_len and padding :D
    encoding = self.tokenizer.encode_plus(
      review,
      add_special_tokens=True,
      max_length=self.max_len,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt', # returned as tensor to ve used in pytorch
      truncation = True
    )

    return {
      'review_text': review,
      'input_ids': encoding['input_ids'].flatten(),
      'attention_mask': encoding['attention_mask'].flatten(),
      'targets': torch.tensor(target, dtype=torch.long)
    }

# %%
# Split
df_train, df_test = train_test_split(df, test_size=0.3, random_state=RANDOM_SEED)
df_val, df_test = train_test_split(df_test, test_size=0.5, random_state=RANDOM_SEED)

# %%
def create_data_loader(df, tokenizer, max_len, batch_size):
  ds = MovieReviewDataset(
    reviews=df.review.to_numpy(),
    targets=df.sentiment.to_numpy(),
    tokenizer=tokenizer,
    max_len=max_len
  )

  return DataLoader(
    ds,
    batch_size=batch_size,
    num_workers=4
  )

train_data_loader = create_data_loader(df_train, tokenizer, MAX_LEN, BATCH_SIZE)
val_data_loader = create_data_loader(df_val, tokenizer, MAX_LEN, BATCH_SIZE)
test_data_loader = create_data_loader(df_test, tokenizer, MAX_LEN, BATCH_SIZE)

# %%
data = next(iter(train_data_loader))
data.keys()

print(data['input_ids'].shape)
print(data['attention_mask'].shape)
print(data['targets'].shape)
# Out:
# torch.Size([16, 400])
# torch.Size([16, 400])
# torch.Size([16])

# %% [markdown]
# We are using the BERT model and build the sentiment classifier on top of it. We then try to use the model on our sample text.

# %%
bert_model = BertModel.from_pretrained(PRE_TRAINED_MODEL_NAME)
# Out:
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]

# %%
print(bert_model)
print(bert_model.config)
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(28996, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSdpaSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )
# BertConfig {
#   "_name_or_path": "bert-base-cased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.41.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }

# %%
# Test Model on smaple txt above
# last_hidden_state,pooler_output,_,_,_,_ = bert_model(
last_hidden_state,pooler_output = bert_model(
  input_ids=encoding['input_ids'],
  attention_mask=encoding['attention_mask']
)

print(last_hidden_state)
print(pooled_output)
# Out:
# last_hidden_state
# pooler_output

# %%
class SentimentClassifier(nn.Module):
    def __init__(self, n_classes):
      super(SentimentClassifier, self).__init__()
      self.bert = BertModel.from_pretrained(PRE_TRAINED_MODEL_NAME)

      self.drop = nn.Dropout(p=0.3)
      self.out = nn.Linear(self.bert.config.hidden_size, n_classes)

    def forward(self, input_ids, attention_mask):
      bert_out = self.bert(
        input_ids=input_ids,
        attention_mask=attention_mask
      )
      pooler_output=bert_out['pooler_output']
      output = self.drop(pooler_output)
      return self.out(output)


# import torch

model = SentimentClassifier(len(class_names))
model = model.to(device)

# torch.cuda.empty_cache()

# %%
# Test Model Code
input_ids = data['input_ids'].to(device)
attention_mask = data['attention_mask'].to(device)

F.softmax(model(input_ids, attention_mask), dim=1)
# Out:
# tensor([[0.6661, 0.3339],
#         [0.5883, 0.4117],
#         [0.4828, 0.5172],
#         [0.5343, 0.4657],
#         [0.6297, 0.3703],
#         [0.6195, 0.3805],
#         [0.5001, 0.4999],
#         [0.4291, 0.5709],
#         [0.5114, 0.4886],
#         [0.5360, 0.4640],
#         [0.5868, 0.4132],
#         [0.6021, 0.3979],
#         [0.4559, 0.5441],
#         [0.6366, 0.3634],
#         [0.5806, 0.4194],
#         [0.5186, 0.4814]], device='cuda:0', grad_fn=<SoftmaxBackward0>)

# %%
optimizer = AdamW(model.parameters(), lr=2e-5, correct_bias=False)

total_steps = len(train_data_loader) * EPOCHS

scheduler = get_linear_schedule_with_warmup(
  optimizer,
  num_warmup_steps=0,
  num_training_steps=total_steps
)

loss_fn = nn.CrossEntropyLoss().to(device)

# %%
def train_epoch(
      model,
      data_loader,
      loss_fn,
      optimizer,
      device,
      scheduler,
      n_examples):

  # Set Training
  model = model.train()

  losses = []
  correct_predictions = 0

  for batch_idx,batch in enumerate(data_loader):
    print(f'[Train]batch {batch_idx + 1}/{len(data_loader)}')
    input_ids = batch["input_ids"].to(device)
    attention_mask = batch["attention_mask"].to(device)
    targets = batch["targets"].to(device)

    outputs = model(
      input_ids=input_ids,
      attention_mask=attention_mask
    )

    _, preds = torch.max(outputs, dim=1)
    loss = loss_fn(outputs, targets)

    correct_predictions += torch.sum(preds == targets)
    losses.append(loss.item())

    loss.backward()

    nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
    optimizer.step()
    scheduler.step()
    optimizer.zero_grad()

    del input_ids
    del attention_mask
    del targets
    del outputs

    torch.cuda.empty_cache()
    gc.collect()


  return correct_predictions.double() / n_examples, np.mean(losses)

# %%
def eval_model(model, data_loader, loss_fn, device, n_examples):
  # Set to Eval Mode
  model = model.eval()

  losses = []
  correct_predictions = 0

  for batch_idx,batch in enumerate(data_loader):
    print(f'[Eval]batch {batch_idx + 1}/{len(data_loader)}')
    # continue
    input_ids = batch["input_ids"].to(device)
    attention_mask = batch["attention_mask"].to(device)
    targets = batch["targets"].to(device)

    outputs = model(
        input_ids=input_ids,
        attention_mask=attention_mask
      )
    _, preds = torch.max(outputs, dim=1)

    loss = loss_fn(outputs, targets)

    correct_predictions += torch.sum(preds == targets)
    losses.append(loss.item())


    del input_ids
    del attention_mask
    del targets
    del outputs

    torch.cuda.empty_cache()
    gc.collect()



  return correct_predictions.double() / n_examples, np.mean(losses)

# %%
# %%time

history = defaultdict(list)
best_accuracy = 0

import torch
import gc


for epoch in range(EPOCHS):

  torch.cuda.empty_cache()
  gc.collect()


  print(f'Epoch {epoch + 1}/{EPOCHS}')
  print('-' * 50)


  train_acc, train_loss = train_epoch(
    model,
    train_data_loader,
    loss_fn,
    optimizer,
    device,
    scheduler,
    len(df_train)
  )
  print(f'Train loss {train_loss} accuracy {train_acc}')

  torch.cuda.empty_cache()
  gc.collect()

  val_acc, val_loss = eval_model(
    model,
    val_data_loader,
    loss_fn,
    device,
    len(df_val)
  )

  print(f'Val   loss {val_loss} accuracy {val_acc}')
  print()

  torch.cuda.empty_cache()
  gc.collect()


  history['train_acc'].append(train_acc)
  history['train_loss'].append(train_loss)
  history['val_acc'].append(val_acc)
  history['val_loss'].append(val_loss)

  if val_acc > best_accuracy:
    torch.save(model.state_dict(), 'best_model_state.bin')
    best_accuracy = val_acc
# Out:
# Epoch 1/2
# --------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# [Train]batch 1971/4375
# [Train]batch 1972/4375
# [Train]batch 1973/4375
# [Train]batch 1974/4375
# [Train]batch 1975/4375
# [Train]batch 1976/4375
# [Train]batch 1977/4375
# [Train]batch 1978/4375
# [Train]batch 1979/4375
# [Train]batch 1980/4375
# [Train]batch 1981/4375
# [Train]batch 1982/4375
# [Train]batch 1983/4375
# [Train]batch 1984/4375
# [Train]batch 1985/4375
# [Train]batch 1986/4375
# [Train]batch 1987/4375
# [Train]batch 1988/4375
# [Train]batch 1989/4375
# [Train]batch 1990/4375
# [Train]batch 1991/4375
# [Train]batch 1992/4375
# [Train]batch 1993/4375
# [Train]batch 1994/4375
# [Train]batch 1995/4375
# [Train]batch 1996/4375
# [Train]batch 1997/4375
# [Train]batch 1998/4375
# [Train]batch 1999/4375
# [Train]batch 2000/4375
# [Train]batch 2001/4375
# [Train]batch 2002/4375
# [Train]batch 2003/4375
# [Train]batch 2004/4375
# [Train]batch 2005/4375
# [Train]batch 2006/4375
# [Train]batch 2007/4375
# [Train]batch 2008/4375
# [Train]batch 2009/4375
# [Train]batch 2010/4375
# [Train]batch 2011/4375
# [Train]batch 2012/4375
# [Train]batch 2013/4375
# [Train]batch 2014/4375
# [Train]batch 2015/4375
# [Train]batch 2016/4375
# [Train]batch 2017/4375
# [Train]batch 2018/4375
# [Train]batch 2019/4375
# [Train]batch 2020/4375
# [Train]batch 2021/4375
# [Train]batch 2022/4375
# [Train]batch 2023/4375
# [Train]batch 2024/4375
# [Train]batch 2025/4375
# [Train]batch 2026/4375
# [Train]batch 2027/4375
# [Train]batch 2028/4375
# [Train]batch 2029/4375
# [Train]batch 2030/4375
# [Train]batch 2031/4375
# [Train]batch 2032/4375
# [Train]batch 2033/4375
# [Train]batch 2034/4375
# [Train]batch 2035/4375
# [Train]batch 2036/4375
# [Train]batch 2037/4375
# [Train]batch 2038/4375
# [Train]batch 2039/4375
# [Train]batch 2040/4375
# ...
# [Eval]batch 645/938
# [Eval]batch 646/938
# [Eval]batch 647/938
# [Eval]batch 648/938
# [Eval]batch 649/938
# [Eval]batch 650/938
# [Eval]batch 651/938
# [Eval]batch 652/938
# [Eval]batch 653/938
# [Eval]batch 654/938
# [Eval]batch 655/938
# [Eval]batch 656/938
# [Eval]batch 657/938
# [Eval]batch 658/938
# [Eval]batch 659/938
# [Eval]batch 660/938
# [Eval]batch 661/938
# [Eval]batch 662/938
# [Eval]batch 663/938
# [Eval]batch 664/938
# [Eval]batch 665/938
# [Eval]batch 666/938
# [Eval]batch 667/938
# [Eval]batch 668/938
# [Eval]batch 669/938
# [Eval]batch 670/938
# [Eval]batch 671/938
# [Eval]batch 672/938
# [Eval]batch 673/938
# [Eval]batch 674/938
# [Eval]batch 675/938
# [Eval]batch 676/938
# [Eval]batch 677/938
# [Eval]batch 678/938
# [Eval]batch 679/938
# [Eval]batch 680/938
# [Eval]batch 681/938
# [Eval]batch 682/938
# [Eval]batch 683/938
# [Eval]batch 684/938
# [Eval]batch 685/938
# [Eval]batch 686/938
# [Eval]batch 687/938
# [Eval]batch 688/938
# [Eval]batch 689/938
# [Eval]batch 690/938
# [Eval]batch 691/938
# [Eval]batch 692/938
# [Eval]batch 693/938
# [Eval]batch 694/938
# [Eval]batch 695/938
# [Eval]batch 696/938
# [Eval]batch 697/938
# [Eval]batch 698/938
# [Eval]batch 699/938
# [Eval]batch 700/938
# [Eval]batch 701/938
# [Eval]batch 702/938
# [Eval]batch 703/938
# [Eval]batch 704/938
# [Eval]batch 705/938
# [Eval]batch 706/938
# [Eval]batch 707/938
# [Eval]batch 708/938
# [Eval]batch 709/938
# [Eval]batch 710/938
# [Eval]batch 711/938
# [Eval]batch 712/938
# [Eval]batch 713/938
# [Eval]batch 714/938
# [Eval]batch 715/938
# [Eval]batch 716/938
# [Eval]batch 717/938
# [Eval]batch 718/938
# [Eval]batch 719/938
# [Eval]batch 720/938
# [Eval]batch 721/938
# [Eval]batch 722/938
# [Eval]batch 723/938
# [Eval]batch 724/938
# [Eval]batch 725/938
# [Eval]batch 726/938
# [Eval]batch 727/938
# [Eval]batch 728/938
# [Eval]batch 729/938
# [Eval]batch 730/938
# [Eval]batch 731/938
# [Eval]batch 732/938
# [Eval]batch 733/938
# [Eval]batch 734/938
# [Eval]batch 735/938
# [Eval]batch 736/938
# [Eval]batch 737/938
# [Eval]batch 738/938
# [Eval]batch 739/938
# [Eval]batch 740/938
# [Eval]batch 741/938
# [Eval]batch 742/938
# [Eval]batch 743/938
# [Eval]batch 744/938
# [Eval]batch 745/938
# [Eval]batch 746/938
# [Eval]batch 747/938
# [Eval]batch 748/938
# [Eval]batch 749/938
# [Eval]batch 750/938
# [Eval]batch 751/938
# [Eval]batch 752/938
# [Eval]batch 753/938
# [Eval]batch 754/938
# [Eval]batch 755/938
# [Eval]batch 756/938
# [Eval]batch 757/938
# [Eval]batch 758/938
# [Eval]batch 759/938
# [Eval]batch 760/938
# [Eval]batch 761/938
# [Eval]batch 762/938
# [Eval]batch 763/938
# [Eval]batch 764/938
# [Eval]batch 765/938
# [Eval]batch 766/938
# [Eval]batch 767/938
# [Eval]batch 768/938
# [Eval]batch 769/938
# [Eval]batch 770/938
# [Eval]batch 771/938
# [Eval]batch 772/938
# [Eval]batch 773/938
# [Eval]batch 774/938
# [Eval]batch 775/938
# [Eval]batch 776/938
# [Eval]batch 777/938
# [Eval]batch 778/938
# [Eval]batch 779/938
# [Eval]batch 780/938
# [Eval]batch 781/938
# [Eval]batch 782/938
# [Eval]batch 783/938
# [Eval]batch 784/938
# [Eval]batch 785/938
# [Eval]batch 786/938
# [Eval]batch 787/938
# [Eval]batch 788/938
# [Eval]batch 789/938
# [Eval]batch 790/938
# [Eval]batch 791/938
# [Eval]batch 792/938
# [Eval]batch 793/938
# [Eval]batch 794/938
# [Eval]batch 795/938
# [Eval]batch 796/938
# [Eval]batch 797/938
# [Eval]batch 798/938
# [Eval]batch 799/938
# [Eval]batch 800/938
# [Eval]batch 801/938
# [Eval]batch 802/938
# [Eval]batch 803/938
# [Eval]batch 804/938
# [Eval]batch 805/938
# [Eval]batch 806/938
# [Eval]batch 807/938
# [Eval]batch 808/938
# [Eval]batch 809/938
# [Eval]batch 810/938
# [Eval]batch 811/938
# [Eval]batch 812/938
# [Eval]batch 813/938
# [Eval]batch 814/938
# [Eval]batch 815/938
# [Eval]batch 816/938
# [Eval]batch 817/938
# [Eval]batch 818/938
# [Eval]batch 819/938
# [Eval]batch 820/938
# [Eval]batch 821/938
# [Eval]batch 822/938
# [Eval]batch 823/938
# [Eval]batch 824/938
# [Eval]batch 825/938
# [Eval]batch 826/938
# [Eval]batch 827/938
# [Eval]batch 828/938
# [Eval]batch 829/938
# [Eval]batch 830/938
# [Eval]batch 831/938
# [Eval]batch 832/938
# [Eval]batch 833/938
# [Eval]batch 834/938
# [Eval]batch 835/938
# [Eval]batch 836/938
# [Eval]batch 837/938
# [Eval]batch 838/938
# [Eval]batch 839/938
# [Eval]batch 840/938
# [Eval]batch 841/938
# [Eval]batch 842/938
# [Eval]batch 843/938
# [Eval]batch 844/938
# [Eval]batch 845/938
# [Eval]batch 846/938
# [Eval]batch 847/938
# [Eval]batch 848/938
# [Eval]batch 849/938
# [Eval]batch 850/938
# [Eval]batch 851/938
# [Eval]batch 852/938
# [Eval]batch 853/938
# [Eval]batch 854/938
# [Eval]batch 855/938
# [Eval]batch 856/938
# [Eval]batch 857/938
# [Eval]batch 858/938
# [Eval]batch 859/938
# [Eval]batch 860/938
# [Eval]batch 861/938
# [Eval]batch 862/938
# [Eval]batch 863/938
# [Eval]batch 864/938
# [Eval]batch 865/938
# [Eval]batch 866/938
# [Eval]batch 867/938
# [Eval]batch 868/938
# [Eval]batch 869/938
# [Eval]batch 870/938
# [Eval]batch 871/938
# [Eval]batch 872/938
# [Eval]batch 873/938
# [Eval]batch 874/938
# [Eval]batch 875/938
# [Eval]batch 876/938
# [Eval]batch 877/938
# [Eval]batch 878/938
# [Eval]batch 879/938
# [Eval]batch 880/938
# [Eval]batch 881/938
# [Eval]batch 882/938
# [Eval]batch 883/938
# [Eval]batch 884/938
# [Eval]batch 885/938
# [Eval]batch 886/938
# [Eval]batch 887/938
# [Eval]batch 888/938
# [Eval]batch 889/938
# [Eval]batch 890/938
# [Eval]batch 891/938
# [Eval]batch 892/938
# [Eval]batch 893/938
# [Eval]batch 894/938
# [Eval]batch 895/938
# [Eval]batch 896/938
# [Eval]batch 897/938
# [Eval]batch 898/938
# [Eval]batch 899/938
# [Eval]batch 900/938
# [Eval]batch 901/938
# [Eval]batch 902/938
# [Eval]batch 903/938
# [Eval]batch 904/938
# [Eval]batch 905/938
# [Eval]batch 906/938
# [Eval]batch 907/938
# [Eval]batch 908/938
# [Eval]batch 909/938
# [Eval]batch 910/938
# [Eval]batch 911/938
# [Eval]batch 912/938
# [Eval]batch 913/938
# [Eval]batch 914/938
# [Eval]batch 915/938
# [Eval]batch 916/938
# [Eval]batch 917/938
# [Eval]batch 918/938
# [Eval]batch 919/938
# [Eval]batch 920/938
# [Eval]batch 921/938
# [Eval]batch 922/938
# [Eval]batch 923/938
# [Eval]batch 924/938
# [Eval]batch 925/938
# [Eval]batch 926/938
# [Train]batch 343/4375
# [Train]batch 344/4375
# [Train]batch 345/4375
# [Train]batch 346/4375
# [Train]batch 347/4375
# [Train]batch 348/4375
# [Train]batch 349/4375
# [Train]batch 350/4375
# [Train]batch 351/4375
# [Train]batch 352/4375
# [Train]batch 353/4375
# [Train]batch 354/4375
# [Train]batch 355/4375
# [Train]batch 356/4375
# [Train]batch 357/4375
# [Train]batch 358/4375
# [Train]batch 359/4375
# [Train]batch 360/4375
# [Train]batch 361/4375
# [Train]batch 362/4375
# [Train]batch 363/4375

# %%
# #  history to CPU

print(history)

history_1={}
history_1['train_acc'] = [h.cpu() for h in history['train_acc']]
history_1['val_acc'] = [h.cpu() for h in history['val_acc']]
print(history_1)

plt.plot(history_1['train_acc'], label='train accuracy')
plt.plot(history_1['val_acc'], label='validation accuracy')

plt.title('Training history')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.xlim(left=0)
plt.ylim([0, 1]);
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
torch.cuda.empty_cache()
gc.collect()

test_acc, _ = eval_model(
  model,
  test_data_loader,
  loss_fn,
  device,
  len(df_test)
)

test_acc.item()

# %%
def get_predictions(model, data_loader):
  # Eval Mode
  model = model.eval()


  review_texts = []
  predictions = []
  prediction_probs = []
  real_values = []


  with torch.no_grad():
    for batch in data_loader:
        texts =batch['review_text']
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        targets = batch["targets"].to(device)


        outputs = model(
          input_ids=input_ids,
          attention_mask=attention_mask
        )
        _, preds = torch.max(outputs, dim=1)

        probs = F.softmax(outputs, dim=1)

        review_texts.extend(texts)
        predictions.extend(preds)
        prediction_probs.extend(probs)
        real_values.extend(targets)


  predictions = torch.stack(predictions).cpu()
  prediction_probs = torch.stack(prediction_probs).cpu()
  real_values = torch.stack(real_values).cpu()
  return review_texts, predictions, prediction_probs, real_values



y_review_texts, y_pred, y_pred_probs, y_test = get_predictions(
  model, test_data_loader)

# %%
print(classification_report(y_test, y_pred, target_names=class_names))

# %%
def show_confusion_matrix(confusion_matrix):
  hmap = sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Blues")
  hmap.yaxis.set_ticklabels(hmap.yaxis.get_ticklabels(), rotation=0, ha='right')
  hmap.xaxis.set_ticklabels(hmap.xaxis.get_ticklabels(), rotation=30, ha='right')
  plt.ylabel('True sentiment')
  plt.xlabel('Predicted sentiment');

cm = confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(cm, index=class_names, columns=class_names)
show_confusion_matrix(df_cm)

# %%
# Inference
idx = 5

review_text = y_review_texts[idx]
true_sentiment = y_test[idx]
pred_sentiment=y_pred[idx]
pred_df = pd.DataFrame({
  'class_names': class_names,
  'values': y_pred_probs[idx]
})

print("\n".join(wrap(review_text)))
print()
print(f'Predicted sentiment: {class_names[pred_sentiment]}')
print(f'True sentiment: {class_names[true_sentiment]}')

# %%
sns.barplot(x='values', y='class_names', data=pred_df, orient='h')
plt.ylabel('sentiment')
plt.xlabel('probability')
plt.xlim([0, 1]);

# %%
import torch
import gc

torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
# !nvidia-smi
# Out:
# Tue May 28 23:43:51 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   74C    P0              38W /  70W |   1689MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+
